# %% [markdown]
# <a href="https://colab.research.google.com/github/IkerRivera/poo-en-phyton-abril-2026/blob/main/poo_Iker_Montoya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Iker Montoy NL = 38 fecha 21/abril/2026
# #### conceptos de programacion (orientada a objeto)s en phyton

# %% [markdown]
# # el prompt en ia gemini
# #lenguaje phyton crear la clase "animal" con los atributos "nombre", "raza" constructor animal y las funciones ladrar() correr() crear los objetos pitbull chihuahua nivel principiente no es interactivo , proporciona tu los datos

# %%
# Definición de la clase Animal
class Animal:
    def __init__(self, nombre, raza):
        self.nombre = nombre
        self.raza = raza

    def ladrar(self):
        print(f"{self.nombre} dice: ¡Guau guau! 🐾")

    def correr(self):
        print(f"{self.nombre} está corriendo velozmente... 🏃‍♂️💨")

    # Nueva función: Acción de morder
    def morder_vecina(self):
        print(f"⚠️ ¡CUIDADO! {self.nombre} ha mordido a la vecina. 👵🚑")

# --- Creación de los objetos ---

# 1. El Pitbull
pitbull = Animal("Rocky", "Pitbull 🐶")

# 2. El Chihuahua
chihuahua = Animal("Fifi", "Chihuahua 🐕")

# 3. El Perro Callejero
callejero = Animal("Firulais", "Callejero (Sultán de la calle) 🦴")

# --- Ejecución de acciones ---

print("--- REPORTE CANINO ---")

# Datos del Pitbull
print(f"Nombre: {pitbull.nombre} | Raza: {pitbull.raza}")
pitbull.ladrar()
print("-" * 30)

# Datos del Chihuahua
print(f"Nombre: {chihuahua.nombre} | Raza: {chihuahua.raza}")
chihuahua.correr()
print("-" * 30)

# Datos del Callejero y el incidente con la vecina
print(f"Nombre: {callejero.nombre} | Raza: {callejero.raza}")
callejero.ladrar()
callejero.morder_vecina() # Aquí activamos la función solicitada
print("programa realizado por iker montoya NL = 38")
# Out:
# --- REPORTE CANINO ---
# Nombre: Rocky | Raza: Pitbull 🐶
# Rocky dice: ¡Guau guau! 🐾
# ------------------------------
# Nombre: Fifi | Raza: Chihuahua 🐕
# Fifi está corriendo velozmente... 🏃‍♂️💨
# ------------------------------
# Nombre: Firulais | Raza: Callejero (Sultán de la calle) 🦴
# Firulais dice: ¡Guau guau! 🐾
# ⚠️ ¡CUIDADO! Firulais ha mordido a la vecina. 👵🚑
# programa realizado por iker montoya NL = 38
